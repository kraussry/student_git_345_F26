# %%
a = 7
pwd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 a = 7
# ----> 2 pwd
#
# NameError: name 'pwd' is not defined

# %%
pwd
# Out:
# '/Users/kraussry/345_lab_git/lab_01_intro_to_Python'

# %%
ls *.csv
# Out:
# data_file1.csv  data_file2.csv  data_file3.csv

# %%
import glob

# %%
csv_files = glob.glob("*.csv")
csv_files
# Out:
# ['data_file2.csv', 'data_file3.csv', 'data_file1.csv']

# %%
for csv in csv_files:
    print(csv)
# Out:
# data_file2.csv
# data_file3.csv
# data_file1.csv

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import control
from numpy import sin, cos, tan, pi
from control import TransferFunction as TF

# %%
t = np.arange(0,1,0.01)

# %%
y = np.sin(2*np.pi*t)

# %%
plt.figure()
plt.plot(t,y)
