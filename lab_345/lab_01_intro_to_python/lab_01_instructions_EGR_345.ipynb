# %% [markdown]
# # Lab 1: Intro to Python

# %% [markdown]
# ## Step 0: Install Anaconda

# %% [markdown]
# - see the notes on Blackboard under "Getting Started with Python"

# %% [markdown]
# ## Python skills you will need for 345 lab:
#
# - basic syntax and creating variables
# - working with Jupyter Notebooks
# - `for` loops
# - `if/then` statements
# - creating functions
# - loading data from text files (`*.csv` or `*.txt`)
# - plotting
# - working with data
# - extracting rows or columns from arrays

# %% [markdown]
# ## Step 1: Introduction to Python and Scientific Python
#
# Download and follow along:
#
# - [intro_to_Python.ipynb](support_materials_for_lab_1/intro_to_Python.ipynb)
# - [intro_to_scientific_and_engineering_python.ipynb](support_materials_for_lab_1/intro_to_scientific_and_engineering_python.ipynb)
# - [for_loops.ipynb](support_materials_for_lab_1/for_loops.ipynb)

# %% [markdown]
# ## Step 2: Essential Python Skills for Data Processing
#
# - [plotting_with_matplotlib.ipynb](support_materials_for_lab_1/plotting_with_matplotlib.ipynb)
# - [slicing_and_indexing.ipynb](support_materials_for_lab_1/slicing_and_indexing.ipynb)

# %% [markdown]
# ## Step 3: Python Tasks for Active Learning

# %% [markdown]
# ### Task 1: Plotting
#
# - generate a plot of a sine wave vs. time:
#     - create a time vector using `np.arange`
#     - use `plt.figure` and `plt.plot` to create the graph
#     - also use `plt.xlabel`, `plt.ylabel`, and `plt.title` to complete the plot
#
# ### Task 2: loadtxt and for loops
#
# - write Python code that finds all of the `*.csv` files in a folder, loads each `*.csv` file into an array, and then generates on plot per file
#     - assume each `*.csv` file contains data in columns where the first column is time
#     - plot the remaining columns vs. time on one plot
#     - the data files may have different numbers of columns in them
#
# - Here are links to three csv files:
#     - [data file 1](https://drive.google.com/open?id=1M8q4apJsByw8Lz5rE_-nCBfUYUDNwdeW)
#     - [data file 2](https://drive.google.com/open?id=1WCuNvv6sNyRbhnU539Dz1A8OiTnckNTf)
#     - [data file 3](https://drive.google.com/open?id=1paEQqDaofhXamcp2qhhYxuGin9MHQt9Q)
#
#
# - download all three files to the same folder
# - use `glob.glob` to find all of the `*.csv` files in a given folder
# - use `np.loadtxt` to load the data from one `*.csv` file into an array
# - use `plt.figure`, `plt.plot`, ... to generate the plots
#
#
# ### Task 3: use `odeint` to numerically solve LA 1
#
# You will eventually solve the differential equation from LA 1 three different ways:
#
# 1. using differential equations
# 2. using `odeint` to numerically solve the differential equations
# 3. using Laplace
#
# You are responsible for reviewing enough differential equations to do it that way.  We will talk about using Laplace next lecture.  For this lab, learn to use `odeint` to numerically find a solution.  Use the built-in Python help along with whatever examples you can find on the internet to help you.  (Yes, you can ask Dr. Krauss if you get stuck.)
